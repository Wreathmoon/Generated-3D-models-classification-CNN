# %%
import stltovoxel
 
import glob # it is going to search in a folder

# %%
run_name = (r'C:\Users\Wreathmoon\Desktop\1\*.stl')
allstls = glob.glob(run_name)
 
for input in allstls:
    resolution = 10
    name = input[30:]
    name = name[:-4]
    name = name + '.xyz'
    output=r'C:\Users\Wreathmoon\Desktop\1\%s'%name
    stltovoxel.convert_file(input, output,resolution)
# Out:
# C:\Users\Wreathmoon\Desktop\1\cube_1.xyz
# Processing layer 0/10
# Processing layer 1/10
# Processing layer 2/10
# Processing layer 3/10
# Processing layer 4/10
# Processing layer 5/10
# Processing layer 6/10
# Processing layer 7/10
# Processing layer 8/10
# Processing layer 9/10
# C:\Users\Wreathmoon\Desktop\1\cube_13.xyz
# Processing layer 0/9
# Processing layer 1/9
# Processing layer 2/9
# Processing layer 3/9
# Processing layer 4/9
# Processing layer 5/9
# Processing layer 6/9
# Processing layer 7/9
# Processing layer 8/9
# C:\Users\Wreathmoon\Desktop\1\cube_2.xyz
# Processing layer 0/8
# Processing layer 1/8
# Processing layer 2/8
# Processing layer 3/8
# Processing layer 4/8
# Processing layer 5/8
# Processing layer 6/8
# Processing layer 7/8
# C:\Users\Wreathmoon\Desktop\1\cube_3.xyz
# Processing layer 0/9
# Processing layer 1/9
# Processing layer 2/9
# Processing layer 3/9
# Processing layer 4/9
# Processing layer 5/9
# Processing layer 6/9
# Processing layer 7/9
# ...
